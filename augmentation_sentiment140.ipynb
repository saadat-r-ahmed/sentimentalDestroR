# %% [markdown]
# # CREAETING THE AUGMENTED DATASET

# %%
# !rm -r venv_txtatck
# !python3.7 -m venv venv_txtatck
# !pip install textattack
# Out:
# Collecting textattack
#   Using cached textattack-0.3.8-py3-none-any.whl (418 kB)
# Collecting num2words
#   Using cached num2words-0.5.12-py3-none-any.whl (125 kB)
# Collecting pycld2
#   Using cached pycld2-0.41-cp37-cp37m-linux_x86_64.whl
# Collecting more-itertools
#   Using cached more_itertools-9.1.0-py3-none-any.whl (54 kB)
# Collecting lru-dict
#   Using cached lru_dict-1.1.8-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (26 kB)
# Collecting filelock
#   Using cached filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Collecting jieba
#   Using cached jieba-0.42.1-py3-none-any.whl
# Collecting scipy>=1.4.1
#   Using cached scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
# Collecting flair
#   Using cached flair-0.12.2-py3-none-any.whl (373 kB)
# Collecting tqdm
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting terminaltables
#   Using cached terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Collecting word2number
#   Using cached word2number-1.1-py3-none-any.whl
# Collecting lemminflect
#   Using cached lemminflect-0.2.3-py3-none-any.whl (769 kB)
# Collecting bert-score>=0.3.5
#   Using cached bert_score-0.3.13-py3-none-any.whl (61 kB)
# Collecting pinyin==0.4.0
#   Using cached pinyin-0.4.0-py3-none-any.whl
# Collecting numpy>=1.21.0
#   Using cached numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (15.7 MB)
# Collecting PySocks!=1.5.7,>=1.5.6
#   Using cached PySocks-1.7.1-py3-none-any.whl (16 kB)
# Collecting pandas>=1.0.1
#   Using cached pandas-1.3.5-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
# Collecting transformers>=4.21.0
#   Using cached transformers-4.28.0-py3-none-any.whl (7.0 MB)
# Collecting datasets==2.4.0
#   Using cached datasets-2.4.0-py3-none-any.whl (365 kB)
# Collecting nltk
#   Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Collecting click<8.1.0
#   Using cached click-8.0.4-py3-none-any.whl (97 kB)
# Collecting editdistance
#   Using cached editdistance-0.6.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (282 kB)
# Collecting torch!=1.8,>=1.7.0
#   Using cached torch-1.13.1-cp37-cp37m-manylinux1_x86_64.whl (887.5 MB)
# Collecting language-tool-python
#   Using cached language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# Collecting OpenHowNet
#   Using cached OpenHowNet-2.0-py3-none-any.whl (18 kB)
# Collecting requests>=2.19.0
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting fsspec[http]>=2021.11.1
#   Using cached fsspec-2023.1.0-py3-none-any.whl (143 kB)
# Collecting dill<0.3.6
#   Using cached dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.14-py37-none-any.whl (115 kB)
# Collecting packaging
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting responses<0.19
#   Using cached responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting aiohttp
#   Using cached aiohttp-3.8.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (948 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Using cached huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
# Collecting importlib-metadata
#   Using cached importlib_metadata-6.3.0-py3-none-any.whl (22 kB)
# Collecting xxhash
#   Using cached xxhash-3.2.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (213 kB)
# Collecting pyarrow>=6.0.0
#   Using cached pyarrow-11.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (35.1 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.5.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
# Collecting pytz>=2017.3
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting python-dateutil>=2.7.3
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting wheel
#   Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: setuptools in ./venv_txtatck/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch!=1.8,>=1.7.0->textattack) (47.1.0)
# Collecting pyyaml>=5.1
#   Using cached PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
# Collecting regex!=2019.12.17
#   Using cached regex-2022.10.31-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Using cached tokenizers-0.13.3-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
# Collecting sqlitedict>=1.6.0
#   Using cached sqlitedict-2.1.0-py3-none-any.whl
# Collecting mpld3==0.3
#   Using cached mpld3-0.3-py3-none-any.whl
# Collecting gdown==4.4.0
#   Using cached gdown-4.4.0-py3-none-any.whl
# Collecting conllu>=4.0
#   Using cached conllu-4.5.2-py2.py3-none-any.whl (16 kB)
# Collecting janome
#   Using cached Janome-0.4.2-py2.py3-none-any.whl (19.7 MB)
# Collecting gensim>=3.8.0
#   Using cached gensim-4.2.0-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (24.1 MB)
# Collecting hyperopt>=0.2.7
#   Using cached hyperopt-0.2.7-py2.py3-none-any.whl (1.6 MB)
# Collecting lxml
#   Using cached lxml-4.9.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_24_x86_64.whl (6.6 MB)
# Collecting wikipedia-api
#   Using cached Wikipedia_API-0.5.8-py3-none-any.whl (13 kB)
# Collecting langdetect
#   Using cached langdetect-1.0.9-py3-none-any.whl
# Collecting transformer-smaller-training-vocab>=0.2.1
#   Using cached transformer_smaller_training_vocab-0.2.3-py3-none-any.whl (12 kB)
# Collecting deprecated>=1.2.4
#   Using cached Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Collecting segtok>=1.5.7
#   Using cached segtok-1.5.11-py3-none-any.whl (24 kB)
# Collecting tabulate
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# Collecting ftfy
#   Using cached ftfy-6.1.1-py3-none-any.whl (53 kB)
# Collecting scikit-learn>=0.21.3
#   Using cached scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
# Collecting pytorch-revgrad
#   Using cached pytorch_revgrad-0.2.0-py3-none-any.whl (4.6 kB)
# Collecting pptree
#   Using cached pptree-3.1-py3-none-any.whl
# Collecting bpemb>=0.3.2
#   Using cached bpemb-0.3.4-py3-none-any.whl (19 kB)
# Collecting boto3
#   Using cached boto3-1.26.113-py3-none-any.whl (135 kB)
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting six
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting joblib
#   Using cached joblib-1.2.0-py3-none-any.whl (297 kB)
# Collecting docopt>=0.6.2
#   Using cached docopt-0.6.2-py2.py3-none-any.whl
# Collecting anytree
#   Using cached anytree-2.8.0-py2.py3-none-any.whl (41 kB)
# Collecting sentencepiece
#   Using cached sentencepiece-0.1.98-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
# Collecting wrapt<2,>=1.10
#   Using cached wrapt-1.15.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (75 kB)
# Collecting charset-normalizer<4.0,>=2.0
#   Using cached charset_normalizer-3.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (171 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Using cached async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting yarl<2.0,>=1.0
#   Using cached yarl-1.8.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (231 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-22.2.0-py3-none-any.whl (60 kB)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting asynctest==0.13.0
#   Using cached asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting multidict<7.0,>=4.5
#   Using cached multidict-6.0.4-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.3.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (148 kB)
# Collecting smart-open>=1.8.1
#   Using cached smart_open-6.3.0-py3-none-any.whl (56 kB)
# Collecting networkx>=2.2
#   Using cached networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Collecting future
#   Using cached future-0.18.3-py3-none-any.whl
# Collecting cloudpickle
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Collecting py4j
#   Using cached py4j-0.10.9.7-py2.py3-none-any.whl (200 kB)
# Collecting pillow>=6.2.0
#   Using cached Pillow-9.5.0-cp37-cp37m-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.38.0-py3-none-any.whl (965 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.1 MB)
# Collecting pyparsing>=2.2.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting urllib3<1.27,>=1.21.1
#   Using cached urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Collecting protobuf<=3.20.2
#   Using cached protobuf-3.20.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (1.0 MB)
# Collecting s3transfer<0.7.0,>=0.6.0
#   Using cached s3transfer-0.6.0-py3-none-any.whl (79 kB)
# Collecting botocore<1.30.0,>=1.29.113
#   Using cached botocore-1.29.113-py3-none-any.whl (10.6 MB)
# Collecting jmespath<2.0.0,>=0.7.1
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting wcwidth>=0.2.5
#   Using cached wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.15.0-py3-none-any.whl (6.8 kB)
# Collecting multiprocess
#   Using cached multiprocess-0.70.13-py37-none-any.whl (115 kB)
# Collecting soupsieve>1.2
#   Using cached soupsieve-2.4-py3-none-any.whl (37 kB)
# Installing collected packages: word2number, wcwidth, tokenizers, sqlitedict, sentencepiece, pytz, pycld2, py4j, pptree, pinyin, mpld3, lru-dict, jieba, janome, docopt, zipp, xxhash, wrapt, wheel, urllib3, typing-extensions, tqdm, threadpoolctl, terminaltables, tabulate, soupsieve, smart-open, six, regex, pyyaml, PySocks, pyparsing, protobuf, pillow, packaging, nvidia-cuda-nvrtc-cu11, numpy, num2words, networkx, multidict, more-itertools, lxml, joblib, jmespath, idna, future, ftfy, fsspec, frozenlist, fonttools, filelock, editdistance, dill, cycler, conllu, cloudpickle, charset-normalizer, certifi, attrs, asynctest, yarl, segtok, scipy, requests, python-dateutil, pyarrow, nvidia-cuda-runtime-cu11, nvidia-cublas-cu11, multiprocess, lemminflect, langdetect, kiwisolver, importlib-metadata, deprecated, beautifulsoup4, async-timeout, anytree, aiosignal, wikipedia-api, scikit-learn, responses, pandas, OpenHowNet, nvidia-cudnn-cu11, matplotlib, language-tool-python, hyperopt, huggingface-hub, gensim, click, botocore, aiohttp, transformers, torch, s3transfer, nltk, gdown, bpemb, pytorch-revgrad, datasets, boto3, bert-score, transformer-smaller-training-vocab, flair, textattack
# Successfully installed OpenHowNet-2.0 PySocks-1.7.1 aiohttp-3.8.4 aiosignal-1.3.1 anytree-2.8.0 async-timeout-4.0.2 asynctest-0.13.0 attrs-22.2.0 beautifulsoup4-4.12.2 bert-score-0.3.13 boto3-1.26.113 botocore-1.29.113 bpemb-0.3.4 certifi-2022.12.7 charset-normalizer-3.1.0 click-8.0.4 cloudpickle-2.2.1 conllu-4.5.2 cycler-0.11.0 datasets-2.4.0 deprecated-1.2.13 dill-0.3.5.1 docopt-0.6.2 editdistance-0.6.2 filelock-3.11.0 flair-0.12.2 fonttools-4.38.0 frozenlist-1.3.3 fsspec-2023.1.0 ftfy-6.1.1 future-0.18.3 gdown-4.4.0 gensim-4.2.0 huggingface-hub-0.13.4 hyperopt-0.2.7 idna-3.4 importlib-metadata-6.3.0 janome-0.4.2 jieba-0.42.1 jmespath-1.0.1 joblib-1.2.0 kiwisolver-1.4.4 langdetect-1.0.9 language-tool-python-2.7.1 lemminflect-0.2.3 lru-dict-1.1.8 lxml-4.9.2 matplotlib-3.5.3 more-itertools-9.1.0 mpld3-0.3 multidict-6.0.4 multiprocess-0.70.13 networkx-2.6.3 nltk-3.8.1 num2words-0.5.12 numpy-1.21.6 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 packaging-23.1 pandas-1.3.5 pillow-9.5.0 pinyin-0.4.0 pptree-3.1 protobuf-3.20.2 py4j-0.10.9.7 pyarrow-11.0.0 pycld2-0.41 pyparsing-3.0.9 python-dateutil-2.8.2 pytorch-revgrad-0.2.0 pytz-2023.3 pyyaml-6.0 regex-2022.10.31 requests-2.28.2 responses-0.18.0 s3transfer-0.6.0 scikit-learn-1.0.2 scipy-1.7.3 segtok-1.5.11 sentencepiece-0.1.98 six-1.16.0 smart-open-6.3.0 soupsieve-2.4 sqlitedict-2.1.0 tabulate-0.9.0 terminaltables-3.1.10 textattack-0.3.8 threadpoolctl-3.1.0 tokenizers-0.13.3 torch-1.13.1 tqdm-4.65.0 transformer-smaller-training-vocab-0.2.3 transformers-4.28.0 typing-extensions-4.5.0 urllib3-1.26.15 wcwidth-0.2.6 wheel-0.40.0 wikipedia-api-0.5.8 word2number-1.1 wrapt-1.15.0 xxhash-3.2.0 yarl-1.8.2 zipp-3.15.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/home/maxwell/Thesis/restructure/venv_txtatck/bin/python3.7 -m pip install --upgrade pip' command.

# %%
from textattack.augmentation.recipes import EasyDataAugmenter
easyAugmenter = EasyDataAugmenter(pct_words_to_swap=0.5, transformations_per_example=1)
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/maxwell/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("Sentiment_Dataset/Sentiment140/Clean/sentiment140.csv", encoding='utf-8')
data = data.iloc[0:50000]

# %%
data['augmented'] = np.nan

# %%
data
# Out:
#        polarity                                              tweet  augmented
# 0             0  VERY SAD! MY BROTHER GOES BACK TO GERMANY TOMO...        NaN
# 1             0  Really sad I can't participate at the bike wee...        NaN
# 2             4                              @iamabhimanyu thanks         NaN
# 3             4  mando diao LIVE @rock am ring 09 so toll und d...        NaN
# 4             0          @n8lewis I wish that I could have helped         NaN
# ...         ...                                                ...        ...
# 49995         0  @astrid_sunrise Aw. I've been trying to convin...        NaN
# 49996         0  first admu-dlsu game on aug. 9 :| i have class...        NaN
# 49997         4  why must wake up so early. I need my sleeeeep....        NaN
# 49998         4                    Quiiierooo ver Up y Star Treck         NaN
# 49999         0  Getting my car fixed. I have to leave it overn...        NaN
#
# [50000 rows x 3 columns]

# %%
from tqdm import tqdm
for i in tqdm(range(len(data))):
    data["augmented"][i] = easyAugmenter.augment(data["tweet"][i])[0]
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]/home/maxwell/Thesis/restructure/venv_txtatck/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/maxwell/Thesis/restructure/venv_txtatck/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 100%|██████████| 50000/50000 [47:41<00:00, 17.47it/s]

# %%
data.to_csv('augmented_sentiment140.csv',encoding='utf-8')

# %% [markdown]
# # CREATING THE PREDICTIONS

# %%
# !python3 -m venv venv_pysentimiento
# !pip install pysentimiento
# !pip install -U scikit-learn
# Out:
# Requirement already satisfied: pysentimiento in ./venv_pysentimiento/lib/python3.7/site-packages (0.4.2)
# Requirement already satisfied: transformers==4.13 in ./venv_pysentimiento/lib/python3.7/site-packages (from pysentimiento) (4.13.0)
# Requirement already satisfied: emoji<2.0.0,>=1.6.1 in ./venv_pysentimiento/lib/python3.7/site-packages (from pysentimiento) (1.7.0)
# Requirement already satisfied: sklearn<0.1,>=0.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from pysentimiento) (0.0.post4)
# Requirement already satisfied: torch<2.0.0,>=1.9.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from pysentimiento) (1.13.1)
# Requirement already satisfied: datasets<2.0.0,>=1.13.3 in ./venv_pysentimiento/lib/python3.7/site-packages (from pysentimiento) (1.18.4)
# Requirement already satisfied: importlib-metadata in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (6.3.0)
# Requirement already satisfied: pyyaml>=5.1 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (6.0)
# Requirement already satisfied: filelock in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (3.11.0)
# Requirement already satisfied: packaging>=20.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (23.1)
# Requirement already satisfied: requests in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (2.28.2)
# Requirement already satisfied: numpy>=1.17 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (1.21.6)
# Requirement already satisfied: sacremoses in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (0.0.53)
# Requirement already satisfied: regex!=2019.12.17 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (2022.10.31)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (0.10.3)
# Requirement already satisfied: tqdm>=4.27 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (4.65.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from transformers==4.13->pysentimiento) (0.13.4)
# Requirement already satisfied: responses<0.19 in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.18.0)
# Requirement already satisfied: pandas in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.3.5)
# Requirement already satisfied: fsspec[http]>=2021.05.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (2023.1.0)
# Requirement already satisfied: xxhash in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (3.2.0)
# Requirement already satisfied: multiprocess in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.70.14)
# Requirement already satisfied: aiohttp in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (3.8.4)
# Requirement already satisfied: dill in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (0.3.6)
# Requirement already satisfied: pyarrow!=4.0.0,>=3.0.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (11.0.0)
# Requirement already satisfied: typing-extensions in ./venv_pysentimiento/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->pysentimiento) (4.5.0)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96 in ./venv_pysentimiento/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->pysentimiento) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99 in ./venv_pysentimiento/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->pysentimiento) (11.7.99)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99 in ./venv_pysentimiento/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->pysentimiento) (11.7.99)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66 in ./venv_pysentimiento/lib/python3.7/site-packages (from torch<2.0.0,>=1.9.0->pysentimiento) (11.10.3.66)
# Requirement already satisfied: setuptools in ./venv_pysentimiento/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.9.0->pysentimiento) (47.1.0)
# Requirement already satisfied: wheel in ./venv_pysentimiento/lib/python3.7/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.9.0->pysentimiento) (0.40.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (1.3.3)
# Requirement already satisfied: attrs>=17.3.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (22.2.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (3.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (1.3.1)
# Requirement already satisfied: asynctest==0.13.0 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (0.13.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./venv_pysentimiento/lib/python3.7/site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (6.0.4)
# Requirement already satisfied: idna<4,>=2.5 in ./venv_pysentimiento/lib/python3.7/site-packages (from requests->transformers==4.13->pysentimiento) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv_pysentimiento/lib/python3.7/site-packages (from requests->transformers==4.13->pysentimiento) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv_pysentimiento/lib/python3.7/site-packages (from requests->transformers==4.13->pysentimiento) (2022.12.7)
# Requirement already satisfied: zipp>=0.5 in ./venv_pysentimiento/lib/python3.7/site-packages (from importlib-metadata->transformers==4.13->pysentimiento) (3.15.0)
# Requirement already satisfied: pytz>=2017.3 in ./venv_pysentimiento/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2023.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in ./venv_pysentimiento/lib/python3.7/site-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2.8.2)
# Requirement already satisfied: click in ./venv_pysentimiento/lib/python3.7/site-packages (from sacremoses->transformers==4.13->pysentimiento) (8.1.3)
# Requirement already satisfied: six in ./venv_pysentimiento/lib/python3.7/site-packages (from sacremoses->transformers==4.13->pysentimiento) (1.16.0)
# Requirement already satisfied: joblib in ./venv_pysentimiento/lib/python3.7/site-packages (from sacremoses->transformers==4.13->pysentimiento) (1.2.0)
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/home/maxwell/Thesis/restructure/venv_pysentimiento/bin/python3 -m pip install --upgrade pip' command.
# Collecting scikit-learn
#   Using cached scikit_learn-1.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (24.8 MB)
# Requirement already satisfied: joblib>=0.11 in ./venv_pysentimiento/lib/python3.7/site-packages (from scikit-learn) (1.2.0)
# Collecting threadpoolctl>=2.0.0
#   Using cached threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: numpy>=1.14.6 in ./venv_pysentimiento/lib/python3.7/site-packages (from scikit-learn) (1.21.6)
# Collecting scipy>=1.1.0
#   Using cached scipy-1.7.3-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (38.1 MB)
# Installing collected packages: threadpoolctl, scipy, scikit-learn
# Successfully installed scikit-learn-1.0.2 scipy-1.7.3 threadpoolctl-3.1.0
# WARNING: You are using pip version 22.0.4; however, version 23.0.1 is available.
# You should consider upgrading via the '/home/maxwell/Thesis/restructure/venv_pysentimiento/bin/python3 -m pip install --upgrade pip' command.

# %%
from pysentimiento import create_analyzer
sentiment_analyzer = create_analyzer(task="sentiment", lang="en")

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
data = pd.read_csv("./Sentiment_Dataset/Sentiment140/Augmented/augmented_sentiment140.csv", encoding='utf-8')

# %%
data['predicted_polarity'] = np.nan
data['augmented_polarity'] = np.nan

# %%
data
# Out:
#        Unnamed: 0  polarity  \
# 0               0         0
# 1               1         0
# 2               2         4
# 3               3         4
# 4               4         0
# ...           ...       ...
# 49995       49995         0
# 49996       49996         0
# 49997       49997         4
# 49998       49998         4
# 49999       49999         0
#
#                                                    tweet  \
# 0      VERY SAD! MY BROTHER GOES BACK TO GERMANY TOMO...
# 1      Really sad I can't participate at the bike wee...
# 2                                  @iamabhimanyu thanks
# 3      mando diao LIVE @rock am ring 09 so toll und d...
# 4              @n8lewis I wish that I could have helped
# ...                                                  ...
# 49995  @astrid_sunrise Aw. I've been trying to convin...
# 49996  first admu-dlsu game on aug. 9 :| i have class...
# 49997  why must wake up so early. I need my sleeeeep....
# 49998                    Quiiierooo ver Up y Star Treck
# 49999  Getting my car fixed. I have to leave it overn...
#
#                                                augmented  predicted_polarity  \
# 0      VERY MY! SAD BACK GOES BROTHER TO GERMANY TOMO...                 NaN
# 1      Really sad really I can't HTTP participate wor...                 NaN
# 2                                   @iamabhimanyu thank                  NaN
# 3      mando diao LIVE @Rock rock am ring MA 09 caree...                 NaN
# 4              @n8lewis that I wish could I have helped                  NaN
# ...                                                  ...                 ...
# 49995  @astrid_sunrise Aw. I've been examine to conve...                 NaN
# 49996  maiden admu-dlsu gamey on aug. IX :| i have cl...                 NaN
# 49997  why I so up wake shelby. must need my sleeeeep...                 NaN
# 49998              Quiiierooo 5 astir y principal Treck                  NaN
# 49999                      car fixed. have it overnight                  NaN
#
#        augmented_polarity
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 49995                 NaN
# 49996                 NaN
# 49997                 NaN
# 49998                 NaN
# 49999                 NaN
#
# [50000 rows x 6 columns]

# %%
for i in tqdm(range(len(data))):

    data['predicted_polarity'][i] = sentiment_analyzer.predict(data['tweet'][i]).output
    data['augmented_polarity'][i] = sentiment_analyzer.predict(data['augmented'][i]).output
# Out:
#   0%|          | 0/50000 [00:00<?, ?it/s]/home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# 100%|██████████| 50000/50000 [09:48<00:00, 85.01it/s]

# %%
data
# Out:
#        Unnamed: 0  polarity  \
# 0               0         0
# 1               1         0
# 2               2         4
# 3               3         4
# 4               4         0
# ...           ...       ...
# 49995       49995         0
# 49996       49996         0
# 49997       49997         4
# 49998       49998         4
# 49999       49999         0
#
#                                                    tweet  \
# 0      VERY SAD! MY BROTHER GOES BACK TO GERMANY TOMO...
# 1      Really sad I can't participate at the bike wee...
# 2                                  @iamabhimanyu thanks
# 3      mando diao LIVE @rock am ring 09 so toll und d...
# 4              @n8lewis I wish that I could have helped
# ...                                                  ...
# 49995  @astrid_sunrise Aw. I've been trying to convin...
# 49996  first admu-dlsu game on aug. 9 :| i have class...
# 49997  why must wake up so early. I need my sleeeeep....
# 49998                    Quiiierooo ver Up y Star Treck
# 49999  Getting my car fixed. I have to leave it overn...
#
#                                                augmented predicted_polarity  \
# 0      VERY MY! SAD BACK GOES BROTHER TO GERMANY TOMO...                NEG
# 1      Really sad really I can't HTTP participate wor...                NEG
# 2                                   @iamabhimanyu thank                 POS
# 3      mando diao LIVE @Rock rock am ring MA 09 caree...                NEU
# 4              @n8lewis that I wish could I have helped                 POS
# ...                                                  ...                ...
# 49995  @astrid_sunrise Aw. I've been examine to conve...                NEG
# 49996  maiden admu-dlsu gamey on aug. IX :| i have cl...                NEU
# 49997  why I so up wake shelby. must need my sleeeeep...                NEG
# 49998              Quiiierooo 5 astir y principal Treck                 NEU
# 49999                      car fixed. have it overnight                 NEU
#
#       augmented_polarity
# 0                    NEG
# 1                    NEG
# 2                    NEU
# 3                    NEU
# 4                    NEU
# ...                  ...
# 49995                NEU
# 49996                NEU
# 49997                NEU
# 49998                NEU
# 49999                NEU
#
# [50000 rows x 6 columns]

# %%
data.to_csv('./Sentiment_Dataset/Sentiment140/Augmented/predicted_sentiment140.csv', encoding='utf-8',index=False)

# %% [markdown]
# # EVALUATION

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
data['polarity'].replace(0,'NEG', inplace=True)
data['polarity'].replace(2,'NEU', inplace=True)
data['polarity'].replace(4,'POS', inplace=True)

# %%
data
# Out:
#        Unnamed: 0 polarity                                              tweet  \
# 0               0      NEG  VERY SAD! MY BROTHER GOES BACK TO GERMANY TOMO...
# 1               1      NEG  Really sad I can't participate at the bike wee...
# 2               2      POS                              @iamabhimanyu thanks
# 3               3      POS  mando diao LIVE @rock am ring 09 so toll und d...
# 4               4      NEG          @n8lewis I wish that I could have helped
# ...           ...      ...                                                ...
# 49995       49995      NEG  @astrid_sunrise Aw. I've been trying to convin...
# 49996       49996      NEG  first admu-dlsu game on aug. 9 :| i have class...
# 49997       49997      POS  why must wake up so early. I need my sleeeeep....
# 49998       49998      POS                    Quiiierooo ver Up y Star Treck
# 49999       49999      NEG  Getting my car fixed. I have to leave it overn...
#
#                                                augmented predicted_polarity  \
# 0      VERY MY! SAD BACK GOES BROTHER TO GERMANY TOMO...                NEG
# 1      Really sad really I can't HTTP participate wor...                NEG
# 2                                   @iamabhimanyu thank                 POS
# 3      mando diao LIVE @Rock rock am ring MA 09 caree...                NEU
# 4              @n8lewis that I wish could I have helped                 POS
# ...                                                  ...                ...
# 49995  @astrid_sunrise Aw. I've been examine to conve...                NEG
# 49996  maiden admu-dlsu gamey on aug. IX :| i have cl...                NEU
# 49997  why I so up wake shelby. must need my sleeeeep...                NEG
# 49998              Quiiierooo 5 astir y principal Treck                 NEU
# 49999                      car fixed. have it overnight                 NEU
#
#       augmented_polarity
# 0                    NEG
# 1                    NEG
# 2                    NEU
# 3                    NEU
# 4                    NEU
# ...                  ...
# 49995                NEU
# 49996                NEU
# 49997                NEU
# 49998                NEU
# 49999                NEU
#
# [50000 rows x 6 columns]

# %%
print("REPORT")
print(classification_report(data['polarity'], data["predicted_polarity"], target_names=['NEG','NEU','POS']))

print("CONFUSSION MATRIX")
print(confusion_matrix(data['polarity'], data["predicted_polarity"]))
# Out:
# REPORT
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          NEG       0.88      0.55      0.68     25092
#          NEU       0.00      0.00      0.00         0
#          POS       0.78      0.62      0.69     24908
#
#     accuracy                           0.58     50000
#    macro avg       0.55      0.39      0.46     50000
# weighted avg       0.83      0.58      0.68     50000
#
# CONFUSSION MATRIX
# [[13751  6959  4382]
#  [    0     0     0]
#  [ 1851  7657 15400]]

# %%
print("REPORT")
print(classification_report(data['polarity'], data["augmented_polarity"], target_names=['NEG','NEU','POS']))

print("CONFUSSION MATRIX")
print(confusion_matrix(data['polarity'], data["augmented_polarity"]))
# Out:
# REPORT
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /home/maxwell/Thesis/restructure/venv_pysentimiento/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
#               precision    recall  f1-score   support
#
#          NEG       0.84      0.41      0.56     25092
#          NEU       0.00      0.00      0.00         0
#          POS       0.76      0.45      0.57     24908
#
#     accuracy                           0.43     50000
#    macro avg       0.53      0.29      0.37     50000
# weighted avg       0.80      0.43      0.56     50000
#
# CONFUSSION MATRIX
# [[10408 11216  3468]
#  [    0     0     0]
#  [ 1977 11701 11230]]

# %%
set(data['polarity'])
# Out:
# {'NEG', 'POS'}
